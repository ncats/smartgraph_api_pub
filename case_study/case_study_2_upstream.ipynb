# %%
# Author: Gergely Zahoranszky-Kohalmi, PhD
#
# Organization: National Center for Advancing Translational Sciences (NCATS/NIH)
#
# Email: gergely.zahoranszky-kohalmi@nih.gov

# %%
# Timer start
import time
start_time = time.perf_counter()

# %%
import requests
import json
import pandas as pd
import networkx as nx
from sg import *
import time

# %%
# Config Section


UNIPROT_PTGS2 = 'P35354'
UNIPROT_CASP8 = 'Q14790'

PPI_DISTANCE = 4
SHORTEST_PATH = True
ACTIVITY_CUTOFF_uM = 1
LIMIT_PREDICTED_COMPOUNDS = 1000

PERTURBATION_MODE = 'target'    # undirected: upstream and downstream | source: downstream only | target: upstream only
CONFIDENCE_CUTOFF = 0


MIN_OVERLAP = 0.75
MAX_OVERLAP = -1    # -1: Not observed, no max ratio imposed

# %%
# Workflow Outline



# 1. Predict molecule COX-2 (PTGS2) UniprotID: P35354

# 2. Take into account the only predicted compoounds that overlap with the respective potent pattern by at least the 80th 
#    percentile overlap ratio value

# 3. Get Upstream regulators of CASP-8 up to distance 2

# 4. See if any of the predicted drugs of for COX-2 is among the known potent molecules of any of the
#    regulators (including CASP-8 modulators)

# %%
def get_predictions (target, limit):
    # target: uniprot ID of target protein
    url_sg = 'https://smartgraph.scb-ncats.io/api/predict/' + target

    cargo = {'limit': limit,
             'format': 'json'}

    headers = {'Content-Type': 'application/json', 'accept': 'application/json'}
    
    print ()
    print ("[->] SmartGraph pathway analysis started ..")
    print ()
    
    try:
        api_response = requests.get(url = url_sg, params=json.dumps(cargo), headers = headers)
    
        result = api_response.json()
    except:
        raise Exception ("[ERROR] Something went wrong when calling SmartGraph endpoint.")
    
    print ("[*] .. SmartGraph pathway analysis done.")
    print()
    print()
    
    return (result)


def assess_perturbation(uniprot_id, shortest_paths_only, max_hops, mode, min_confidence):
    
    #urls = parse_urls (FILE_URLS)
    url_sg = 'https://smartgraph.scb-ncats.io/api/path_regulatory_open'
    
    headers = {'Content-Type': 'application/json', 'accept': 'application/json'}
    
    cargo = {
          "uniprot_ids": [
            uniprot_id
          ],
          "shortest_paths": shortest_paths_only,
          "max_length": max_hops,
          "explore_mode": mode,
          "confidence_cutoff": min_confidence
        }
    
    print ()
    print ("[->] SmartGraph pathway analysis started ..")
    print ()
    
    try:
        api_response = requests.post(url = url_sg, data=json.dumps(cargo), headers = headers)
    
        result = api_response.json()
    except:
        raise Exception ("[ERROR] Something went wrong when calling SmartGraph endpoint.")
    
    print ("[*] .. SmartGraph pathway analysis done.")
    print()
    print()
    
    return (result)



def get_potent_compounds (uniprot_id, cutoff_in_uM = 10):
    # only activity values of the defined cutoff (in uM unit) and less (i.e. more potent) will be reported

    
    url_sg = 'https://smartgraph.scb-ncats.io/api/bioactivity_target'
    
    headers = {'Content-Type': 'application/json', 'accept': 'application/json'}
    
    cargo = {
              "target_uniprot_ids": [
                uniprot_id
              ],
              "activity_cutoff": cutoff_in_uM,
              "activity_type": "activity"
            }



    
    print ()
    print ("[->] SmartGraph potent compounds analysis started ..")
    print ()
    
    try:
        api_response = requests.post(url = url_sg, data=json.dumps(cargo), headers = headers)
    
        result = api_response.json()
    except:
        raise Exception ("[ERROR] Something went wrong when calling SmartGraph endpoint.")
    
    print ("[*] .. SmartGraph potent compounds analysis done.")
    print()
    print()


    
    
    return (result)


def filter_predicted_compounds (G, min_ratio = 0, max_ratio = -1):
    filtered_compounds = set()
    
    for start_node, end_node, e_attributes in G.edges(data = True):
        #print (e_attributes)

        if (e_attributes['edge_type'] == 'pattern_of') and (e_attributes['ratio'] >= min_ratio):
            
            if  (max_ratio != -1):
                
                if (e_attributes['ratio'] <= max_ratio):
                    filtered_compounds.add(end_node)
                
            else:
                filtered_compounds.add(end_node)  

    return (filtered_compounds)
                

def create_prediction_subgraph (G, filtered_compounds):
    # filtered compounds is a set, like = set ()
    
    S = G.copy()
    
    nodes = set()
    nodes = filtered_compounds

    
    for n, n_attr in S.nodes(data = True):
        
        if n_attr['node_type'] == 'target':
            nodes.add(n)
    
    
    S = S.subgraph(nodes)

    R = S.copy()

    targets = []
    compounds = []    

    for n, n_attr in S.nodes(data = True):
        
        if n_attr['node_type'] == 'target':
            targets.append(n)
        
        elif n_attr['node_type'] == 'compound':
            compounds.append(n)

    for c in compounds:
        for t in targets:
            R.add_edge (c, t)

    for start_node, end_node, e_attr in R.edges(data = True):
        R[start_node][end_node]['start_node'] = start_node
        R[start_node][end_node]['end_node'] = end_node
        R[start_node][end_node]['edge_type'] = 'predicted_dti'
        


    return (R)


def get_target_nodes (G):
    targets = []
    for n, n_attr in G.nodes(data = True):
        if n_attr['node_type'] == 'target':
            targets.append (n)

    targets = list(set(targets))
    
    return (targets)

# %%
# Step 1


# 1. Predict molecule COX-2 (PTGS2) UniprotID: P35354


sg_json = get_predictions (UNIPROT_PTGS2, LIMIT_PREDICTED_COMPOUNDS)

G = sg_json2graph (sg_json)

cy_json = graph2cyjs (G)

visualize_in_cytoscape (cy_json)
# Out:
# [->] SmartGraph pathway analysis started ..
#
# [*] .. SmartGraph pathway analysis done.
#
#
# DiGraph with 318 nodes and 317 edges
# Network created with SUID: 728941
# Network view created.
# Existing styles: ['Curved', 'Sample1', 'BioPAX_SIF_0', 'Marquee', 'Big Labels', 'default black', 'size_rank', 'Sample3', 'default', 'Gradient1', 'SynGPS', 'Ripple', 'BioPAX_0', 'SynGPS API', 'BioPAX', 'Nested Network Style', 'Solid', 'Universe', 'Directed', 'Minimal', 'Sample2', 'BioPAX_SIF']
# Creating new style 'SmartGraph API'.
# New style 'SmartGraph API' created.
# Style 'SmartGraph API' applied to the network.
# Layout 'grid' applied to the network.

# %%
# Step 2.

# 2. Take into account the only predicted compoounds that overlap with the respective potent pattern by at least the 80th 
#    percentile overlap ratio value

filtered_compounds = filter_predicted_compounds (G, min_ratio = 0.75, max_ratio = -1)

print (filtered_compounds)



P = create_prediction_subgraph (G, filtered_compounds)

cy_json = graph2cyjs (P)

visualize_in_cytoscape (cy_json)




# 4. See if any of the predicted drugs of for COX-2 is among the known potent molecules of any of the
#    regulators (including CASP-8 modulators)



S = P.copy()
# Out:
# {'WDGYCEHMFMSJEW-UHFFFAOYSA-N', 'NRRDZUADGNIUCD-UHFFFAOYSA-N', 'OXGUCUVFOIWWQJ-WLTRVTDYSA-N', 'KXFAISXPYYJVCJ-GRSHGNNSSA-N', 'PZZRDJXEMZMZFD-IEGSVRCHSA-N', 'JPUKWEQWGBDDQB-QSOFNFLRSA-N', 'DGJYBDOWQFCDHE-UHFFFAOYSA-N', 'PZZRDJXEMZMZFD-SQIUQIIDSA-N', 'GXDOWNQTKLTXEW-UHFFFAOYSA-N', 'XJMXHTQZLWXEDW-UHFFFAOYSA-N', 'INHCQGHDHUOQIX-UHFFFAOYSA-N', 'RUAGOKUSUUWRQE-UHFFFAOYSA-N', 'FUFKFSVXLFTGSP-UHFFFAOYSA-N', 'RNVUDWOQYYWXBJ-IEGSVRCHSA-N', 'WSIZFTULXCTIHZ-UHFFFAOYSA-N', 'SJKDLOJANSYBDC-UHFFFAOYSA-N', 'MYPBQYHRXMVYIY-UHFFFAOYSA-N', 'UMUBKDCPBROUFT-UHFFFAOYSA-N', 'QDGLVKCJNVHFCT-NDENLUEZSA-N', 'OHCLXXFQIPGZRS-UHFFFAOYSA-N', 'YKEOPYUONVHGAZ-JPJNWVEQSA-N', 'PZZRDJXEMZMZFD-ZMQFRBSTSA-N', 'DNITTWSXYHDGKU-UHFFFAOYSA-N', 'TWKARRBOKOIBHF-UHFFFAOYSA-N', 'KYQBXJFBRGTRJO-UHFFFAOYSA-N', 'SQOFVHPBOAQZCT-UHFFFAOYSA-N', 'RBZAXFZNNVDTJO-UHFFFAOYSA-N', 'LCKGEDRQDVZBSX-UHFFFAOYSA-N', 'ZGCKMTQNGWQKEN-VQHVLOKHSA-N', 'NUFNGCDVYZKSKE-HOHGHBTGSA-N', 'FEISFUIEFYIRAS-DHZHZOJOSA-N', 'KWYARAWBLOGQHJ-UHFFFAOYSA-N', 'PZZRDJXEMZMZFD-BWYUNELBSA-N', 'PZZRDJXEMZMZFD-VHICIVCISA-N', 'JPUKWEQWGBDDQB-DTGCRPNFSA-N', 'PNRSDASMCVWNMM-AAFJCEBUSA-N', 'OXGUCUVFOIWWQJ-HQBVPOQASA-N', 'ZYMSQNYLOOUQLZ-UHFFFAOYSA-N', 'WRXUDNPJNMUPKL-UHFFFAOYSA-N', 'MUAFFFYJFXPGHN-UHFFFAOYSA-N', 'XOLKAZNYFNYAOI-UHFFFAOYSA-N', 'OFPXSFXSNFPTHF-UHFFFAOYSA-N', 'ZWRVNGVRWVVOMO-UHFFFAOYSA-N', 'ONXUHKXDKGXHFK-IZZDOVSWSA-N', 'GWTVMUKCRYINJA-UHFFFAOYSA-N', 'DEFJNMAYHJWPGH-UHFFFAOYSA-N', 'DALHZLWHRFISAI-UHFFFAOYSA-N', 'QIAZLAMZVBDHGZ-UHFFFAOYSA-N', 'BHJMSGWGUFQZNI-UHFFFAOYSA-N', 'MFRZHGSWQHNIEA-UKTHLTGXSA-N', 'LDPBTGBWTUWCBU-UHFFFAOYSA-N', 'SOSLMHZOJATCCP-AEIZVZFYSA-N', 'MQCDKKPPNBPSIO-UHFFFAOYSA-N', 'LXIKEPCNDFVJKC-QXMHVHEDSA-M', 'ZTDOHOYJYCVVKC-UHFFFAOYSA-N', 'KYQBXJFBRGTRJO-UHFFFAOYSA-M', 'JSBOHMYHRMOLNZ-UHFFFAOYSA-N', 'VASRVOKCIPXPBF-UHFFFAOYSA-N', 'OFPXSFXSNFPTHF-UHFFFAOYSA-M', 'RKCOTKNKKXMGTC-UHFFFAOYSA-N', 'GLPCILHGXWHENJ-UHFFFAOYSA-N', 'OLGIPHPPQCDVAE-UHFFFAOYSA-N', 'BPDLSIWDDLHHMB-UHFFFAOYSA-N', 'JRFRHWWGWXVBAN-UNOMPAQXSA-N'}
# Network created with SUID: 732309
# Network view created.
# Existing styles: ['Curved', 'Sample1', 'BioPAX_SIF_0', 'Marquee', 'Big Labels', 'default black', 'size_rank', 'Sample3', 'default', 'Gradient1', 'SynGPS', 'Ripple', 'BioPAX_0', 'SynGPS API', 'BioPAX', 'Nested Network Style', 'Solid', 'Universe', 'SmartGraph API', 'Directed', 'Minimal', 'Sample2', 'BioPAX_SIF']
# Creating new style 'SmartGraph API'.
# New style 'SmartGraph API' created.
# Style 'SmartGraph API' applied to the network.
# Layout 'grid' applied to the network.

# %%
# Step 3.

# 3. Get Upstream regulators of CASP-8 up to distance 2

# Regulatory path open ended (start or end node), i.e. undirected, max step: 2

# Target: Q14790 (Casp-8)

# curl -X 'GET' \
#   'https://smartgraph.scb-ncats.io/api/path_regulatory_open/Q14790?shortest_paths=true&max_length=2&explore_mode=undirected&confidence_cutoff=0&format=json' \
#   -H 'accept: application/json'

sg_json = assess_perturbation (UNIPROT_CASP8, SHORTEST_PATH, PPI_DISTANCE, PERTURBATION_MODE, CONFIDENCE_CUTOFF)


#print (sg_json)

print ('orig PPI graph')
H = sg_json2graph (sg_json)

#print (H)
cy_json_H = graph2cyjs (H)
visualize_in_cytoscape (cy_json_H)


# Iterate through all *upstream* targets, get target- compounds pairs, 




# this will be a Set:
#ancestors = nx.ancestors(H, UNIPROT_CASP8)

#print (ancestors)
#ancestors_l = list(ancestors)

#print (ancestors_l)


# Adding study subject node back to nodes to create the upstream-targey induced subgraph
#ancestors.add(UNIPROT_CASP8)


#A = H.subgraph(ancestors)


#print ('ancestor induced subgraph')
#print (A)




S = nx.compose(S, H)

#cy_json = graph2cyjs (A)

#visualize_in_cytoscape (cy_json)





# Get potent compounds of study_subject
# unit returned by SmartGraph API is in uM

dti_casp8_json = get_potent_compounds (UNIPROT_CASP8, cutoff_in_uM = ACTIVITY_CUTOFF_uM)

C_0 = sg_json2graph (dti_casp8_json)



#S = nx.compose(S, A)

S = nx.compose(S, C_0)

cy_json = graph2cyjs (S)

visualize_in_cytoscape (cy_json)






# Get potent compoudns of upstream neighbors

networks = {}


targets = get_target_nodes (H)

nr_targets = len(targets)
idx = 1

for target in targets:

    print (f'[*] Processing target nr. {idx} of total {nr_targets} targets.')
    idx += 1
    
    if target != UNIPROT_CASP8 and target != UNIPROT_PTGS2:
        potent_compounds = get_potent_compounds (target, cutoff_in_uM = ACTIVITY_CUTOFF_uM)
        networks[target] = sg_json2graph (potent_compounds)


for ancestor in networks.keys():
    if ancestor != UNIPROT_CASP8 and ancestor != UNIPROT_PTGS2:
    
        A = networks[ancestor]
    
        # Note DTI already contains the STUDYSUBJECT TARGET's potent compounds
        S = nx.compose(S, A)

cy_json = graph2cyjs (S)


# Timer Stop
end_time = time.perf_counter()
duration = end_time - start_time
print(f'[*] Workflow duration (before last visualization step): {duration:.1f} sec')

visualize_in_cytoscape (cy_json)
# Out:
# [->] SmartGraph pathway analysis started ..
#
# [*] .. SmartGraph pathway analysis done.
#
#
# orig PPI graph
# DiGraph with 766 nodes and 781 edges
# Network created with SUID: 733119
# Network view created.
# Existing styles: ['Sample1', 'Marquee', 'Sample3', 'SynGPS', 'BioPAX_0', 'Nested Network Style', 'Solid', 'Universe', 'SmartGraph API', 'Sample2', 'BioPAX_SIF', 'SmartGraph API_0', 'Curved', 'BioPAX_SIF_0', 'Big Labels', 'default black', 'size_rank', 'default', 'Gradient1', 'Ripple', 'SynGPS API', 'BioPAX', 'Directed', 'Minimal']
# Creating new style 'SmartGraph API'.
# New style 'SmartGraph API' created.
# Style 'SmartGraph API' applied to the network.
# Layout 'grid' applied to the network.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 240 nodes and 239 edges
# Network created with SUID: 741031
# Network view created.
# Existing styles: ['Sample1', 'Marquee', 'Sample3', 'SynGPS', 'BioPAX_0', 'Nested Network Style', 'Solid', 'Universe', 'SmartGraph API', 'Sample2', 'BioPAX_SIF', 'SmartGraph API_0', 'Curved', 'BioPAX_SIF_0', 'Big Labels', 'default black', 'size_rank', 'default', 'Gradient1', 'Ripple', 'SynGPS API', 'BioPAX', 'SmartGraph API_1', 'Directed', 'Minimal']
# Creating new style 'SmartGraph API'.
# New style 'SmartGraph API' created.
# Style 'SmartGraph API' applied to the network.
# Layout 'grid' applied to the network.
# [*] Processing target nr. 1 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 2 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 284 nodes and 283 edges
# [*] Processing target nr. 3 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 4 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 5 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 58 nodes and 57 edges
# [*] Processing target nr. 6 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 7 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 8 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 9 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 5 nodes and 4 edges
# [*] Processing target nr. 10 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 11 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 12 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 399 nodes and 398 edges
# [*] Processing target nr. 13 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 14 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 15 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 16 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 17 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 18 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 1473 nodes and 1472 edges
# [*] Processing target nr. 19 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 2 nodes and 1 edges
# [*] Processing target nr. 20 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 21 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 22 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 23 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 1438 nodes and 1437 edges
# [*] Processing target nr. 24 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 41 nodes and 40 edges
# [*] Processing target nr. 25 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 26 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 252 nodes and 251 edges
# [*] Processing target nr. 27 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 147 nodes and 146 edges
# [*] Processing target nr. 28 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 29 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 46 nodes and 45 edges
# [*] Processing target nr. 30 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 4 nodes and 3 edges
# [*] Processing target nr. 31 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 435 nodes and 434 edges
# [*] Processing target nr. 32 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 51 nodes and 50 edges
# [*] Processing target nr. 33 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 53 nodes and 52 edges
# [*] Processing target nr. 34 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 173 nodes and 172 edges
# [*] Processing target nr. 35 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 5 nodes and 4 edges
# [*] Processing target nr. 36 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 378 nodes and 377 edges
# [*] Processing target nr. 37 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 7 nodes and 6 edges
# [*] Processing target nr. 38 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 39 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 40 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 41 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 42 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 43 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 44 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 12 nodes and 11 edges
# [*] Processing target nr. 45 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 46 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 20 nodes and 19 edges
# [*] Processing target nr. 47 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 48 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 49 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 50 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 51 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 772 nodes and 771 edges
# [*] Processing target nr. 52 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 88 nodes and 87 edges
# [*] Processing target nr. 53 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 540 nodes and 539 edges
# [*] Processing target nr. 54 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 21 nodes and 20 edges
# [*] Processing target nr. 55 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 56 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 57 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 58 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 59 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 60 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 15 nodes and 14 edges
# [*] Processing target nr. 61 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 62 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 63 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 23 nodes and 22 edges
# [*] Processing target nr. 64 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 65 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 66 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 67 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 2 nodes and 1 edges
# [*] Processing target nr. 68 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 69 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 2 nodes and 1 edges
# [*] Processing target nr. 70 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 71 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 848 nodes and 847 edges
# [*] Processing target nr. 72 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 73 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 74 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 75 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 76 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 107 nodes and 106 edges
# [*] Processing target nr. 77 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 9 nodes and 8 edges
# [*] Processing target nr. 78 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 79 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 2 nodes and 1 edges
# [*] Processing target nr. 80 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 1187 nodes and 1186 edges
# [*] Processing target nr. 81 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 82 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 83 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 84 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 85 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 86 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 87 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 88 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 89 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 90 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 91 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 92 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 3 nodes and 2 edges
# [*] Processing target nr. 93 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 2 nodes and 1 edges
# [*] Processing target nr. 94 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 184 nodes and 183 edges
# [*] Processing target nr. 95 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 96 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 97 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 98 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 2 nodes and 1 edges
# [*] Processing target nr. 99 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 100 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 101 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 56 nodes and 55 edges
# [*] Processing target nr. 102 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 103 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 10 nodes and 9 edges
# [*] Processing target nr. 104 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 105 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 8 nodes and 7 edges
# [*] Processing target nr. 106 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 107 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 15 nodes and 14 edges
# [*] Processing target nr. 108 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 110 nodes and 109 edges
# [*] Processing target nr. 109 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 110 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 111 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 112 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 113 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 114 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 115 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 52 nodes and 51 edges
# [*] Processing target nr. 116 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 117 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 5 nodes and 4 edges
# [*] Processing target nr. 118 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 119 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 120 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 13 nodes and 12 edges
# [*] Processing target nr. 121 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 24 nodes and 23 edges
# [*] Processing target nr. 122 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 123 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 39 nodes and 38 edges
# [*] Processing target nr. 124 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 125 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 317 nodes and 316 edges
# [*] Processing target nr. 126 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 46 nodes and 45 edges
# [*] Processing target nr. 127 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 128 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 951 nodes and 950 edges
# [*] Processing target nr. 129 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 130 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 2 nodes and 1 edges
# [*] Processing target nr. 131 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 132 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 133 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 226 nodes and 225 edges
# [*] Processing target nr. 134 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 272 nodes and 271 edges
# [*] Processing target nr. 135 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 3903 nodes and 3902 edges
# [*] Processing target nr. 136 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 137 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 138 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 139 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 140 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 141 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 142 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 143 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 144 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 145 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 146 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 16 nodes and 15 edges
# [*] Processing target nr. 147 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 36 nodes and 35 edges
# [*] Processing target nr. 148 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 149 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 150 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 151 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 152 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 153 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 2488 nodes and 2487 edges
# [*] Processing target nr. 154 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 155 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 29 nodes and 28 edges
# [*] Processing target nr. 156 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 157 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 2 nodes and 1 edges
# [*] Processing target nr. 158 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 159 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 160 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 161 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 162 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 163 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 59 nodes and 58 edges
# [*] Processing target nr. 164 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 3 nodes and 2 edges
# [*] Processing target nr. 165 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 166 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 167 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 168 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 8 nodes and 7 edges
# [*] Processing target nr. 169 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 170 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 171 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 172 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 11 nodes and 10 edges
# [*] Processing target nr. 173 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 174 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 107 nodes and 106 edges
# [*] Processing target nr. 175 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 176 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 177 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 3176 nodes and 3175 edges
# [*] Processing target nr. 178 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 5 nodes and 4 edges
# [*] Processing target nr. 179 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 30 nodes and 29 edges
# [*] Processing target nr. 180 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 181 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 182 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 183 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 184 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 46 nodes and 45 edges
# [*] Processing target nr. 185 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 186 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 203 nodes and 202 edges
# [*] Processing target nr. 187 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 188 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 189 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 377 nodes and 376 edges
# [*] Processing target nr. 190 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 191 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 192 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 766 nodes and 765 edges
# [*] Processing target nr. 193 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 492 nodes and 491 edges
# [*] Processing target nr. 194 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 195 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 20 nodes and 19 edges
# [*] Processing target nr. 196 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 197 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 2089 nodes and 2088 edges
# [*] Processing target nr. 198 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 639 nodes and 638 edges
# [*] Processing target nr. 199 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 4 nodes and 3 edges
# [*] Processing target nr. 200 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 201 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 202 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 9 nodes and 8 edges
# [*] Processing target nr. 203 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 7 nodes and 6 edges
# [*] Processing target nr. 204 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 205 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 206 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 207 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 208 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 209 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 210 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 419 nodes and 418 edges
# [*] Processing target nr. 211 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 212 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 213 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 214 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 91 nodes and 90 edges
# [*] Processing target nr. 215 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 216 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 217 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 218 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 219 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 220 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 221 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 222 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 223 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 94 nodes and 93 edges
# [*] Processing target nr. 224 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 225 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 6 nodes and 5 edges
# [*] Processing target nr. 226 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 227 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 228 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 26 nodes and 25 edges
# [*] Processing target nr. 229 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 230 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 133 nodes and 132 edges
# [*] Processing target nr. 231 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 2 nodes and 1 edges
# [*] Processing target nr. 232 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 11 nodes and 10 edges
# [*] Processing target nr. 233 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 234 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 22 nodes and 21 edges
# [*] Processing target nr. 235 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 236 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 2 nodes and 1 edges
# [*] Processing target nr. 237 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 246 nodes and 245 edges
# [*] Processing target nr. 238 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 239 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 16 nodes and 15 edges
# [*] Processing target nr. 240 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 241 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 2 nodes and 1 edges
# [*] Processing target nr. 242 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 22 nodes and 21 edges
# ...
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 253 nodes and 252 edges
# [*] Processing target nr. 688 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 689 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 690 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 2 nodes and 1 edges
# [*] Processing target nr. 691 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 692 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 5 nodes and 4 edges
# [*] Processing target nr. 693 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 694 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 695 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 696 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 697 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 17 nodes and 16 edges
# [*] Processing target nr. 698 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 699 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 700 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 701 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 69 nodes and 68 edges
# [*] Processing target nr. 702 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 703 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 106 nodes and 105 edges
# [*] Processing target nr. 704 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 705 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 295 nodes and 294 edges
# [*] Processing target nr. 706 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 707 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 708 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 709 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 216 nodes and 215 edges
# [*] Processing target nr. 710 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 11 nodes and 10 edges
# [*] Processing target nr. 711 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 712 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 713 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 97 nodes and 96 edges
# [*] Processing target nr. 714 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 715 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 716 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 87 nodes and 86 edges
# [*] Processing target nr. 717 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 11 nodes and 10 edges
# [*] Processing target nr. 718 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 1437 nodes and 1436 edges
# [*] Processing target nr. 719 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 13 nodes and 12 edges
# [*] Processing target nr. 720 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 721 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 722 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 1331 nodes and 1330 edges
# [*] Processing target nr. 723 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 724 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 160 nodes and 159 edges
# [*] Processing target nr. 725 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 61 nodes and 60 edges
# [*] Processing target nr. 726 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 727 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 42 nodes and 41 edges
# [*] Processing target nr. 728 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 87 nodes and 86 edges
# [*] Processing target nr. 729 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 730 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 580 nodes and 579 edges
# [*] Processing target nr. 731 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 732 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 26 nodes and 25 edges
# [*] Processing target nr. 733 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 262 nodes and 261 edges
# [*] Processing target nr. 734 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 3 nodes and 2 edges
# [*] Processing target nr. 735 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 135 nodes and 134 edges
# [*] Processing target nr. 736 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 21 nodes and 20 edges
# [*] Processing target nr. 737 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 738 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 739 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 740 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 741 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 94 nodes and 93 edges
# [*] Processing target nr. 742 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 743 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 744 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 745 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 746 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 747 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 539 nodes and 538 edges
# [*] Processing target nr. 748 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 749 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 3 nodes and 2 edges
# [*] Processing target nr. 750 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 751 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 2 nodes and 1 edges
# [*] Processing target nr. 752 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 6 nodes and 5 edges
# [*] Processing target nr. 753 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 754 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 755 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 756 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 21 nodes and 20 edges
# [*] Processing target nr. 757 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 12 nodes and 11 edges
# [*] Processing target nr. 758 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 759 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 84 nodes and 83 edges
# [*] Processing target nr. 760 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 67 nodes and 66 edges
# [*] Processing target nr. 761 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 762 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 763 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 764 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 765 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 0 nodes and 0 edges
# [*] Processing target nr. 766 of total 766 targets.
#
# [->] SmartGraph potent compounds analysis started ..
#
# [*] .. SmartGraph potent compounds analysis done.
#
#
# DiGraph with 3 nodes and 2 edges
# [*] Workflow duration (before last visualization step): 280.2 sec
# Network created with SUID: 752323
# Network view created.
# Existing styles: ['Sample1', 'Marquee', 'Sample3', 'SynGPS', 'BioPAX_0', 'Nested Network Style', 'Solid', 'Universe', 'SmartGraph API', 'Sample2', 'BioPAX_SIF', 'SmartGraph API_0', 'Curved', 'BioPAX_SIF_0', 'Big Labels', 'default black', 'size_rank', 'default', 'Gradient1', 'Ripple', 'SynGPS API', 'BioPAX', 'SmartGraph API_2', 'SmartGraph API_1', 'Directed', 'Minimal']
# Creating new style 'SmartGraph API'.
# New style 'SmartGraph API' created.
# Style 'SmartGraph API' applied to the network.
# Layout 'grid' applied to the network.

# %%
# Timer Stop
end_time = time.perf_counter()
duration = end_time - start_time
print(f'[*] Workflow duration: {duration:.1f} sec')
# Out:
# [*] Workflow duration: 286.2 sec

# %%
# Ref: https://www.freecodecamp.org/news/loading-a-json-file-in-python-how-to-read-and-parse-json/
# Ref: https://networkx.org/documentation/stable/reference/readwrite/generated/networkx.readwrite.json_graph.cytoscape_data.html#networkx.readwrite.json_graph.cytoscape_data
# Ref: https://networkx.org/documentation/stable/reference/readwrite/generated/networkx.readwrite.json_graph.cytoscape_graph.html
# Ref: https://groups.google.com/g/cytoscape-helpdesk/c/keumGM-bwz0
# Ref: https://networkx.org/documentation/networkx-1.9/reference/generated/networkx.readwrite.graphml.write_graphml.html
# Ref: https://github.com/cytoscape/copycat-layout/blob/master/notebooks/Copycat%20Automation%20Example.ipynb
# Ref: ChatGPT 4.0 [https://chat.openai.com]
# Ref: https://www.geeksforgeeks.org/python-map-function/
# Ref: https://stackoverflow.com/questions/24898797/check-if-key-exists-and-iterate-the-json-array-using-python
# Ref: https://htmlcolorcodes.com/colors/brick-red/
# Ref: https://stackoverflow.com/questions/32652149/combine-join-networkx-graphs
# Ref: https://networkx.org/documentation/stable/reference/classes/generated/networkx.Graph.copy.html
# Ref: https://www.w3schools.com/python/ref_requests_get.asp
# Ref: https://builtin.com/articles/timing-functions-python
